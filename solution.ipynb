# %% [markdown]
# # 1.- Exploratory Data Analysis

# %% [markdown]
# ## import python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

import solutionlib as sollib

# %% [markdown]
# ## reading dataset

# %%
data = pd.read_excel("BBDD_Hospitalización.xlsx")
print(f'There are {data.shape[0]} Rows and {data.shape[1]} Columns')
# Out:
# There are 570 Rows and 20 Columns

# %%
#data.head()

# %%
#data.tail()

# %%
data.describe()
# Out:
#              EDAD         PSA  NUMERO DE MUESTRAS TOMADAS  \
# count  568.000000  564.000000                  568.000000
# mean    63.882042   13.271401                   12.996479
# std      9.281517   15.668966                    3.921180
# min     39.000000    0.600000                    4.000000
# 25%     59.000000    5.600000                   12.000000
# 50%     64.000000    8.000000                   12.000000
# 75%     69.000000   15.000000                   12.000000
# max    151.000000  100.000000                   24.000000
#
#        DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# count               568.000000                568.000000
# mean                  0.165493                  0.014085
# std                   0.958066                  0.196474
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                  12.000000                  3.000000

# %% [markdown]
# ## Looking for null values

# %%
mis_val = data.isnull().sum()
not_null_val = data.notnull().sum()
mis_val_percent = 100 * data.isnull().sum() / len(data)
mz_table = pd.concat([not_null_val, mis_val, mis_val_percent], axis=1)
mz_table = mz_table.rename(
columns = {0 : 'Not Null', 1 : 'Missing Values', 2 : '% of Total Values'})

mz_table['Data Type'] = data.dtypes
mz_table = mz_table[
mz_table.iloc[:,1] != 0].sort_values(
'% of Total Values', ascending=False).round(3)
mz_table
# Out:
#                                                     Not Null  Missing Values  \
# AGENTE AISLADO                                           551              19
# PSA                                                      564               6
# HOSPITALIZACION                                          565               5
# BIOPSIAS PREVIAS                                         566               4
# ENF. CRONICA PULMONAR OBSTRUCTIVA                        566               4
# VOLUMEN PROSTATICO                                       567               3
# CUP                                                      567               3
# EDAD                                                     568               2
# ITU                                                      568               2
# DIAS HOSPITALIZACION MQ                                  568               2
# PATRON DE RESISTENCIA                                    568               2
# TIPO DE CULTIVO                                          568               2
# BIOPSIA                                                  568               2
# FIEBRE                                                   568               2
# NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA ...       568               2
# DIABETES                                                 568               2
# NUMERO DE MUESTRAS TOMADAS                               568               2
# ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS                  568               2
# HOSPITALIZACIÓN ULTIMO MES                               568               2
# DIAS HOSPITALIZACIÓN UPC                                 568               2
#
#                                                     % of Total Values  \
# AGENTE AISLADO                                                  3.333
# PSA                                                             1.053
# HOSPITALIZACION                                                 0.877
# BIOPSIAS PREVIAS                                                0.702
# ENF. CRONICA PULMONAR OBSTRUCTIVA                               0.702
# VOLUMEN PROSTATICO                                              0.526
# CUP                                                             0.526
# EDAD                                                            0.351
# ITU                                                             0.351
# DIAS HOSPITALIZACION MQ                                         0.351
# PATRON DE RESISTENCIA                                           0.351
# TIPO DE CULTIVO                                                 0.351
# BIOPSIA                                                         0.351
# FIEBRE                                                          0.351
# NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA ...              0.351
# DIABETES                                                        0.351
# NUMERO DE MUESTRAS TOMADAS                                      0.351
# ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS                         0.351
# HOSPITALIZACIÓN ULTIMO MES                                      0.351
# DIAS HOSPITALIZACIÓN UPC                                        0.351
#
#                                                    Data Type
# AGENTE AISLADO                                        object
# PSA                                                  float64
# HOSPITALIZACION                                       object
# BIOPSIAS PREVIAS                                      object
# ENF. CRONICA PULMONAR OBSTRUCTIVA                     object
# VOLUMEN PROSTATICO                                    object
# CUP                                                   object
# EDAD                                                 float64
# ITU                                                   object
# DIAS HOSPITALIZACION MQ                              float64
# PATRON DE RESISTENCIA                                 object
# TIPO DE CULTIVO                                       object
# BIOPSIA                                               object
# FIEBRE                                                object
# NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA ...    object
# DIABETES                                              object
# NUMERO DE MUESTRAS TOMADAS                           float64
# ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS               object
# HOSPITALIZACIÓN ULTIMO MES                            object
# DIAS HOSPITALIZACIÓN UPC                             float64
